# %% [markdown]
# # Bekiaris-Liberis & Krstic 2017 audit
# Repository-based CPU re-execution notebook. The original paper PDF is not required for the numerical runner.

# %%
# !pip -q install numpy scipy numba matplotlib pytest pymupdf nbformat

# %%
# !rm -rf /content/krstic-2016-reproduction
# !git clone -q https://github.com/KK1182112KK/krstic-2016-reproduction.git /content/krstic-2016-reproduction
# %cd /content/krstic-2016-reproduction/bekiaris-liberis-krstic-2017-reproduction

# %%
# !python -m pytest -q test_audit.py

# %%
# !python audit.py --out regenerated-results

# %%
# !python continuous_reference.py
# !python postprocess.py
